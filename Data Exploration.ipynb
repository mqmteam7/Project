# %% [markdown]
# ## Data exploration

# %%
import pandas as pd  
import numpy as np
import matplotlib.pyplot as plt

# %%
# Reading in the data
RepRisk = pd.read_csv('1. Data\RepRisk.csv',
                         parse_dates=['date','peak_RRI_date'],
                         index_col=['date']).dropna()

RepRisk.head(5)
# Out:
#             RepRisk_ID  current_RRI  RRI_trend  peak_RRI peak_RRI_date  \
# date
# 2007-11-30          10           34         10        41    2006-08-25
# 2018-07-31          10           16         -2        34    2017-02-27
# 2017-03-31          10           25         -9        34    2017-02-27
# 2011-08-31          10           22         -2        31    2010-05-18
# 2015-01-31          10           21         -1        34    2014-09-24
#
#            RepRisk_rating  country_sector_average environmental_percentage  \
# date
# 2007-11-30            BBB                      13                      40%
# 2018-07-31            BBB                      34                       0%
# 2017-03-31              A                      23                       0%
# 2011-08-31             BB                      45                      29%
# 2015-01-31             BB                      39                      17%
#
# ...
